# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-38da9f84-1067-46bb-a662-1879e132a466" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38da9f84-1067-46bb-a662-1879e132a466">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ionosphere_data.csv to ionosphere_data.csv

# %%
df = pd.read_csv(io.BytesIO(uploaded['ionosphere_data.csv']), delimiter=',')

# %%
df.head()
# Out:
#    feature1  feature2  feature3  ...  feature33  feature34  label
# 0         1         0   0.99539  ...    0.18641   -0.45300      g
# 1         1         0   1.00000  ...   -0.13738   -0.02447      b
# 2         1         0   1.00000  ...    0.56045   -0.38238      g
# 3         1         0   1.00000  ...   -0.32382    1.00000      b
# 4         1         0   1.00000  ...   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
df.shape
# Out:
# (351, 35)

# %%
df.describe().T
# Out:
#            count      mean       std  min       25%      50%       75%  max
# feature1   351.0  0.891738  0.311155  0.0  1.000000  1.00000  1.000000  1.0
# feature2   351.0  0.000000  0.000000  0.0  0.000000  0.00000  0.000000  0.0
# feature3   351.0  0.641342  0.497708 -1.0  0.472135  0.87111  1.000000  1.0
# feature4   351.0  0.044372  0.441435 -1.0 -0.064735  0.01631  0.194185  1.0
# feature5   351.0  0.601068  0.519862 -1.0  0.412660  0.80920  1.000000  1.0
# feature6   351.0  0.115889  0.460810 -1.0 -0.024795  0.02280  0.334655  1.0
# feature7   351.0  0.550095  0.492654 -1.0  0.211310  0.72873  0.969240  1.0
# feature8   351.0  0.119360  0.520750 -1.0 -0.054840  0.01471  0.445675  1.0
# feature9   351.0  0.511848  0.507066 -1.0  0.087110  0.68421  0.953240  1.0
# feature10  351.0  0.181345  0.483851 -1.0 -0.048075  0.01829  0.534195  1.0
# feature11  351.0  0.476183  0.563496 -1.0  0.021120  0.66798  0.957895  1.0
# feature12  351.0  0.155040  0.494817 -1.0 -0.065265  0.02825  0.482375  1.0
# feature13  351.0  0.400801  0.622186 -1.0  0.000000  0.64407  0.955505  1.0
# feature14  351.0  0.093414  0.494873 -1.0 -0.073725  0.03027  0.374860  1.0
# feature15  351.0  0.344159  0.652828 -1.0  0.000000  0.60194  0.919330  1.0
# feature16  351.0  0.071132  0.458371 -1.0 -0.081705  0.00000  0.308975  1.0
# feature17  351.0  0.381949  0.618020 -1.0  0.000000  0.59091  0.935705  1.0
# feature18  351.0 -0.003617  0.496762 -1.0 -0.225690  0.00000  0.195285  1.0
# feature19  351.0  0.359390  0.626267 -1.0  0.000000  0.57619  0.899265  1.0
# feature20  351.0 -0.024025  0.519076 -1.0 -0.234670  0.00000  0.134370  1.0
# feature21  351.0  0.336695  0.609828 -1.0  0.000000  0.49909  0.894865  1.0
# feature22  351.0  0.008296  0.518166 -1.0 -0.243870  0.00000  0.188760  1.0
# feature23  351.0  0.362475  0.603767 -1.0  0.000000  0.53176  0.911235  1.0
# feature24  351.0 -0.057406  0.527456 -1.0 -0.366885  0.00000  0.164630  1.0
# feature25  351.0  0.396135  0.578451 -1.0  0.000000  0.55389  0.905240  1.0
# feature26  351.0 -0.071187  0.508495 -1.0 -0.332390 -0.01505  0.156765  1.0
# feature27  351.0  0.541641  0.516205 -1.0  0.286435  0.70824  0.999945  1.0
# feature28  351.0 -0.069538  0.550025 -1.0 -0.443165 -0.01769  0.153535  1.0
# feature29  351.0  0.378445  0.575886 -1.0  0.000000  0.49664  0.883465  1.0
# feature30  351.0 -0.027907  0.507974 -1.0 -0.236885  0.00000  0.154075  1.0
# feature31  351.0  0.352514  0.571483 -1.0  0.000000  0.44277  0.857620  1.0
# feature32  351.0 -0.003794  0.513574 -1.0 -0.242595  0.00000  0.200120  1.0
# feature33  351.0  0.349364  0.522663 -1.0  0.000000  0.40956  0.813765  1.0
# feature34  351.0  0.014480  0.468337 -1.0 -0.165350  0.00000  0.171660  1.0

# %%
for feature in df:
    print(feature)
    print(len(df[feature].unique()))
# Out:
# feature1
# 2
# feature2
# 1
# feature3
# 219
# feature4
# 269
# feature5
# 204
# feature6
# 259
# feature7
# 231
# feature8
# 260
# feature9
# 244
# feature10
# 267
# feature11
# 246
# feature12
# 269
# feature13
# 238
# feature14
# 266
# feature15
# 234
# feature16
# 270
# feature17
# 254
# feature18
# 280
# feature19
# 254
# feature20
# 266
# feature21
# 248
# feature22
# 265
# feature23
# 248
# feature24
# 264
# feature25
# 256
# feature26
# 273
# feature27
# 256
# feature28
# 281
# feature29
# 244
# feature30
# 266
# feature31
# 243
# feature32
# 263
# feature33
# 245
# feature34
# 263
# label
# 2

# %%
df['feature2'].unique()
# Out:
# array([0])

# %%
df.drop(df.columns[1], inplace=True, axis=1)

# %%
df.head()
# Out:
#    feature1  feature3  feature4  ...  feature33  feature34  label
# 0         1   0.99539  -0.05889  ...    0.18641   -0.45300      g
# 1         1   1.00000  -0.18829  ...   -0.13738   -0.02447      b
# 2         1   1.00000  -0.03365  ...    0.56045   -0.38238      g
# 3         1   1.00000  -0.45161  ...   -0.32382    1.00000      b
# 4         1   1.00000  -0.02401  ...   -0.04608   -0.65697      g
#
# [5 rows x 34 columns]

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 34 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature3   351 non-null    float64
#  2   feature4   351 non-null    float64
#  3   feature5   351 non-null    float64
#  4   feature6   351 non-null    float64
#  5   feature7   351 non-null    float64
#  6   feature8   351 non-null    float64
#  7   feature9   351 non-null    float64
#  8   feature10  351 non-null    float64
#  9   feature11  351 non-null    float64
#  10  feature12  351 non-null    float64
#  11  feature13  351 non-null    float64
#  12  feature14  351 non-null    float64
#  13  feature15  351 non-null    float64
#  14  feature16  351 non-null    float64
#  15  feature17  351 non-null    float64
#  16  feature18  351 non-null    float64
#  17  feature19  351 non-null    float64
#  18  feature20  351 non-null    float64
#  19  feature21  351 non-null    float64
#  20  feature22  351 non-null    float64
#  21  feature23  351 non-null    float64
#  22  feature24  351 non-null    float64
#  23  feature25  351 non-null    float64
#  24  feature26  351 non-null    float64
#  25  feature27  351 non-null    float64
#  26  feature28  351 non-null    float64
#  27  feature29  351 non-null    float64
#  28  feature30  351 non-null    float64
#  29  feature31  351 non-null    float64
#  30  feature32  351 non-null    float64
#  31  feature33  351 non-null    float64
#  32  feature34  351 non-null    float64
#  33  label      351 non-null    object
# dtypes: float64(32), int64(1), object(1)
# memory usage: 93.4+ KB

# %%
for feature in df:
    print(feature)
    df[feature].hist()
    plt.show()
# Out:
# feature1
# feature3
# feature4
# feature5
# feature6
# feature7
# feature8
# feature9
# feature10
# feature11
# feature12
# feature13
# feature14
# feature15
# feature16
# feature17
# feature18
# feature19
# feature20
# feature21
# feature22
# feature23
# feature24
# feature25
# feature26
# feature27
# feature28
# feature29
# feature30
# feature31
# feature32
# feature33
# feature34
# label

# %%
df.describe()
# Out:
#          feature1    feature3    feature4  ...   feature32   feature33   feature34
# count  351.000000  351.000000  351.000000  ...  351.000000  351.000000  351.000000
# mean     0.891738    0.641342    0.044372  ...   -0.003794    0.349364    0.014480
# std      0.311155    0.497708    0.441435  ...    0.513574    0.522663    0.468337
# min      0.000000   -1.000000   -1.000000  ...   -1.000000   -1.000000   -1.000000
# 25%      1.000000    0.472135   -0.064735  ...   -0.242595    0.000000   -0.165350
# 50%      1.000000    0.871110    0.016310  ...    0.000000    0.409560    0.000000
# 75%      1.000000    1.000000    0.194185  ...    0.200120    0.813765    0.171660
# max      1.000000    1.000000    1.000000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 33 columns]

# %%
# Find missing values
df.isnull().sum()
# Out:
# feature1     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %%
df['label'] = [1 if lbl == 'g' else 0 for lbl in df['label']]

# %%
train_data = df.sample(frac= 0.6, random_state=125)
test_data = df.drop(train_data.index)

# %%
train_label = train_data.iloc[:,-1]
train_data = train_data.iloc[:,0:-1]
test_label = test_data.iloc[:,-1]
test_data = test_data.iloc[:,0:-1]

# %%
train_data.head()
# Out:
#      feature1  feature3  feature4  ...  feature32  feature33  feature34
# 270         1   1.00000   0.08013  ...   -0.03464    0.92226   -0.03673
# 116         1   1.00000  -0.14754  ...   -0.44262    0.49180   -0.06557
# 135         1   0.89706   0.38235  ...   -0.50735   -0.28676   -0.56618
# 91          1   0.84557  -0.08580  ...   -0.78170   -0.18494   -0.59867
# 100         1   1.00000  -1.00000  ...   -1.00000    0.00000    0.00000
#
# [5 rows x 33 columns]

# %%
train_label
# Out:
# 270    1
# 116    0
# 135    1
# 91     0
# 100    0
#       ..
# 213    1
# 161    1
# 141    1
# 59     0
# 113    1
# Name: label, Length: 211, dtype: int64

# %% [markdown]
# - Standardized the Input Variables. **Hint**: Centeralized the data

# %%
train_data.shape
# Out:
# (211, 33)

# %%
test_data.shape
# Out:
# (140, 33)

# %%
train_label.shape
# Out:
# (211,)

# %%
test_label.shape
# Out:
# (140,)

# %%
train_label.sum()
# Out:
# 140

# %%
len(train_label)
# Out:
# 211

# %%
train_data = train_data.to_numpy()

# %%
train_label = train_label.to_numpy().astype('float32')

# %%
test_data = test_data.to_numpy()

# %%
test_label = test_label.to_numpy().astype('float32')

# %%
print(type(train_data))
print(type(train_label))
print(type(test_data))
print(type(test_label))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(train_data.dtype)
print(train_label.dtype)
print(test_label.dtype)
print(test_data.dtype)
# Out:
# float64
# float32
# float32
# float64

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(train_data.shape[1],)))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,  activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 64)                2176
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 6,401
# Trainable params: 6,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'RMSprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_data, train_label, validation_split=0.2, epochs=100, batch_size = 16)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 19ms/step - loss: 0.6804 - accuracy: 0.6119 - val_loss: 0.5286 - val_accuracy: 0.6977
# Epoch 2/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5922 - accuracy: 0.6533 - val_loss: 0.4747 - val_accuracy: 0.6977
# Epoch 3/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5652 - accuracy: 0.6957 - val_loss: 0.4365 - val_accuracy: 0.7442
# Epoch 4/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5150 - accuracy: 0.7048 - val_loss: 0.3899 - val_accuracy: 0.8372
# Epoch 5/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4195 - accuracy: 0.8507 - val_loss: 0.3484 - val_accuracy: 0.8837
# Epoch 6/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4259 - accuracy: 0.8404 - val_loss: 0.3126 - val_accuracy: 0.8837
# Epoch 7/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4055 - accuracy: 0.8614 - val_loss: 0.2835 - val_accuracy: 0.8837
# Epoch 8/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3796 - accuracy: 0.8697 - val_loss: 0.2515 - val_accuracy: 0.9070
# Epoch 9/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3007 - accuracy: 0.9171 - val_loss: 0.2238 - val_accuracy: 0.9302
# Epoch 10/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2671 - accuracy: 0.9325 - val_loss: 0.2138 - val_accuracy: 0.9302
# Epoch 11/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2650 - accuracy: 0.9255 - val_loss: 0.1899 - val_accuracy: 0.9535
# Epoch 12/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2586 - accuracy: 0.9373 - val_loss: 0.1722 - val_accuracy: 0.9535
# Epoch 13/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2337 - accuracy: 0.9100 - val_loss: 0.1571 - val_accuracy: 0.9535
# Epoch 14/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1596 - accuracy: 0.9672 - val_loss: 0.1498 - val_accuracy: 0.9535
# Epoch 15/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1867 - accuracy: 0.9458 - val_loss: 0.1415 - val_accuracy: 0.9535
# Epoch 16/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1946 - accuracy: 0.9488 - val_loss: 0.1295 - val_accuracy: 0.9767
# Epoch 17/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1848 - accuracy: 0.9385 - val_loss: 0.1253 - val_accuracy: 0.9535
# Epoch 18/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1581 - accuracy: 0.9544 - val_loss: 0.1236 - val_accuracy: 0.9767
# Epoch 19/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1666 - accuracy: 0.9192 - val_loss: 0.1135 - val_accuracy: 0.9767
# Epoch 20/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1323 - accuracy: 0.9624 - val_loss: 0.1110 - val_accuracy: 0.9767
# Epoch 21/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1281 - accuracy: 0.9692 - val_loss: 0.1109 - val_accuracy: 0.9767
# Epoch 22/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1490 - accuracy: 0.9615 - val_loss: 0.1075 - val_accuracy: 0.9767
# Epoch 23/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1417 - accuracy: 0.9564 - val_loss: 0.1058 - val_accuracy: 0.9767
# Epoch 24/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1330 - accuracy: 0.9601 - val_loss: 0.1191 - val_accuracy: 0.9767
# Epoch 25/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1391 - accuracy: 0.9468 - val_loss: 0.0987 - val_accuracy: 0.9767
# Epoch 26/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0945 - accuracy: 0.9758 - val_loss: 0.1057 - val_accuracy: 0.9535
# Epoch 27/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1280 - accuracy: 0.9538 - val_loss: 0.0992 - val_accuracy: 0.9767
# Epoch 28/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1117 - accuracy: 0.9757 - val_loss: 0.0955 - val_accuracy: 0.9535
# Epoch 29/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1029 - accuracy: 0.9650 - val_loss: 0.0924 - val_accuracy: 0.9535
# Epoch 30/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1466 - accuracy: 0.9411 - val_loss: 0.0895 - val_accuracy: 0.9535
# Epoch 31/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0605 - accuracy: 0.9955 - val_loss: 0.0856 - val_accuracy: 0.9535
# Epoch 32/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0577 - accuracy: 0.9836 - val_loss: 0.0723 - val_accuracy: 0.9767
# Epoch 33/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0746 - accuracy: 0.9847 - val_loss: 0.0866 - val_accuracy: 0.9535
# Epoch 34/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0608 - accuracy: 0.9883 - val_loss: 0.0657 - val_accuracy: 1.0000
# Epoch 35/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0514 - accuracy: 0.9958 - val_loss: 0.0721 - val_accuracy: 0.9535
# Epoch 36/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0846 - accuracy: 0.9740 - val_loss: 0.0806 - val_accuracy: 0.9535
# Epoch 37/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0981 - accuracy: 0.9822 - val_loss: 0.0863 - val_accuracy: 0.9535
# Epoch 38/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0469 - accuracy: 0.9860 - val_loss: 0.0655 - val_accuracy: 0.9535
# Epoch 39/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0513 - accuracy: 0.9958 - val_loss: 0.0603 - val_accuracy: 0.9535
# Epoch 40/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0583 - accuracy: 0.9847 - val_loss: 0.0581 - val_accuracy: 0.9767
# Epoch 41/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0649 - accuracy: 0.9813 - val_loss: 0.0555 - val_accuracy: 0.9767
# Epoch 42/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0551 - accuracy: 0.9890 - val_loss: 0.0797 - val_accuracy: 0.9535
# Epoch 43/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9844 - val_loss: 0.0606 - val_accuracy: 0.9535
# Epoch 44/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0449 - accuracy: 0.9926 - val_loss: 0.0490 - val_accuracy: 0.9767
# Epoch 45/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0772 - accuracy: 0.9698 - val_loss: 0.0559 - val_accuracy: 0.9535
# Epoch 46/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0616 - accuracy: 0.9755 - val_loss: 0.0567 - val_accuracy: 0.9535
# Epoch 47/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0726 - accuracy: 0.9753 - val_loss: 0.0512 - val_accuracy: 0.9767
# Epoch 48/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0591 - accuracy: 0.9946 - val_loss: 0.0524 - val_accuracy: 0.9767
# Epoch 49/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0389 - accuracy: 0.9931 - val_loss: 0.0528 - val_accuracy: 0.9767
# Epoch 50/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0567 - accuracy: 0.9818 - val_loss: 0.0527 - val_accuracy: 0.9767
# Epoch 51/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0404 - accuracy: 0.9931 - val_loss: 0.0585 - val_accuracy: 0.9767
# Epoch 52/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0387 - accuracy: 0.9822 - val_loss: 0.0594 - val_accuracy: 0.9767
# Epoch 53/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0502 - accuracy: 0.9794 - val_loss: 0.0660 - val_accuracy: 0.9767
# Epoch 54/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0222 - accuracy: 0.9985 - val_loss: 0.0584 - val_accuracy: 0.9767
# Epoch 55/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0251 - accuracy: 0.9979 - val_loss: 0.0669 - val_accuracy: 0.9767
# Epoch 56/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 0.9979 - val_loss: 0.0640 - val_accuracy: 0.9767
# Epoch 57/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0362 - accuracy: 0.9862 - val_loss: 0.0693 - val_accuracy: 0.9767
# Epoch 58/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0284 - accuracy: 0.9979 - val_loss: 0.0711 - val_accuracy: 0.9767
# Epoch 59/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0317 - accuracy: 0.9901 - val_loss: 0.0615 - val_accuracy: 0.9767
# Epoch 60/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0197 - accuracy: 0.9979 - val_loss: 0.0734 - val_accuracy: 0.9767
# Epoch 61/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0139 - accuracy: 0.9973 - val_loss: 0.0712 - val_accuracy: 0.9767
# Epoch 62/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0136 - accuracy: 0.9985 - val_loss: 0.0660 - val_accuracy: 0.9767
# Epoch 63/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9767
# Epoch 64/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0219 - accuracy: 0.9973 - val_loss: 0.0721 - val_accuracy: 0.9767
# Epoch 65/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0358 - accuracy: 0.9916 - val_loss: 0.0727 - val_accuracy: 0.9767
# Epoch 66/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9767
# Epoch 67/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9973 - val_loss: 0.0786 - val_accuracy: 0.9767
# Epoch 68/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 0.9965 - val_loss: 0.0846 - val_accuracy: 0.9767
# Epoch 69/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0824 - val_accuracy: 0.9767
# Epoch 70/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0146 - accuracy: 0.9956 - val_loss: 0.0859 - val_accuracy: 0.9767
# Epoch 71/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0236 - accuracy: 0.9916 - val_loss: 0.0998 - val_accuracy: 0.9767
# Epoch 72/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0223 - accuracy: 0.9890 - val_loss: 0.1058 - val_accuracy: 0.9767
# Epoch 73/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.1082 - val_accuracy: 0.9767
# Epoch 74/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.1062 - val_accuracy: 0.9767
# Epoch 75/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.1091 - val_accuracy: 0.9767
# Epoch 76/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9767
# Epoch 77/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9767
# Epoch 78/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9767
# Epoch 79/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1200 - val_accuracy: 0.9767
# Epoch 80/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9767
# Epoch 81/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 0.9956 - val_loss: 0.1499 - val_accuracy: 0.9767
# Epoch 82/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.1557 - val_accuracy: 0.9767
# Epoch 83/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9767
# Epoch 84/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0214 - accuracy: 0.9822 - val_loss: 0.1402 - val_accuracy: 0.9767
# Epoch 85/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9767
# Epoch 86/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9767
# Epoch 87/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9767
# Epoch 88/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9767
# Epoch 89/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.1708 - val_accuracy: 0.9767
# Epoch 90/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0268 - accuracy: 0.9838 - val_loss: 0.1720 - val_accuracy: 0.9767
# Epoch 91/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9979 - val_loss: 0.1722 - val_accuracy: 0.9767
# Epoch 92/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1730 - val_accuracy: 0.9767
# Epoch 93/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9767
# Epoch 94/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1703 - val_accuracy: 0.9767
# Epoch 95/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1737 - val_accuracy: 0.9767
# Epoch 96/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1795 - val_accuracy: 0.9535
# Epoch 97/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1925 - val_accuracy: 0.9767
# Epoch 98/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1949 - val_accuracy: 0.9767
# Epoch 99/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1959 - val_accuracy: 0.9767
# Epoch 100/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1820 - val_accuracy: 0.9767

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(100)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
plt.plot(epochs, acc_values, 'bo', label='Training acc')
plt.plot(epochs, val_acc_values, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
score = model.evaluate(test_data, test_label)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3811 - accuracy: 0.9357

# %%
score
# Out:
# [0.3811015784740448, 0.9357143044471741]

# %%
predictions=model.predict(test_data)

# %%
y_pred = (predictions > 0.5)

# %%
tf.math.confusion_matrix(
    test_label, y_pred, num_classes=2, weights=None, dtype=tf.dtypes.int32,
    name=None
)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[47,  8],
#        [ 1, 84]], dtype=int32)>

# %%
np.count_nonzero(y_pred)
# Out:
# 92
