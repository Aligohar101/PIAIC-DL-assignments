# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers as L
from tensorflow.keras import models as M

# %%
import io
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-26e3f560-66f4-4ab2-ae70-a3143b6e82b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26e3f560-66f4-4ab2-ae70-a3143b6e82b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving compresive_strength_concrete.csv to compresive_strength_concrete (1).csv

# %%
data = pd.read_csv(io.BytesIO(uploaded['compresive_strength_concrete.csv']))
data
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# 0                                         540.0  ...                                             79.99
# 1                                         540.0  ...                                             61.89
# 2                                         332.5  ...                                             40.27
# 3                                         332.5  ...                                             41.05
# 4                                         198.6  ...                                             44.30
# ...                                         ...  ...                                               ...
# 1025                                      276.4  ...                                             44.28
# 1026                                      322.2  ...                                             31.18
# 1027                                      148.5  ...                                             23.70
# 1028                                      159.1  ...                                             32.77
# 1029                                      260.9  ...                                             32.40
#
# [1030 rows x 9 columns]

# %%
data.shape
# Out:
# (1030, 9)

# %%
data.isnull().sum()
# Out:
# Cement (component 1)(kg in a m^3 mixture)                0
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    0
# Fly Ash (component 3)(kg in a m^3 mixture)               0
# Water  (component 4)(kg in a m^3 mixture)                0
# Superplasticizer (component 5)(kg in a m^3 mixture)      0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     0
# Fine Aggregate (component 7)(kg in a m^3 mixture)        0
# Age (day)                                                0
# Concrete compressive strength(MPa, megapascals)          0
# dtype: int64

# %%
X_train = data.sample(frac = 0.7, random_state = 123)
X_test = data.drop(X_train.index)

# %%
X_train.head()
# Out:
#      Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# 134                                      362.6  ...                                             71.30
# 13                                       190.0  ...                                             42.33
# 996                                      152.6  ...                                             26.86
# 770                                      349.0  ...                                             14.99
# 937                                      313.3  ...                                             36.80
#
# [5 rows x 9 columns]

# %%
Y_train = X_train.iloc[:,-1]
X_train = X_train.iloc[:,0:-1]
Y_test = X_test.iloc[:,-1]
X_test = X_test.iloc[:,0:-1]

# %%
X_mean = X_train.mean()
X_train -= X_mean
X_std = X_train.std()
X_train /= X_std
X_test -= X_mean
X_test /= X_std

# %%
Y_mean = Y_train.mean()
Y_train -= Y_mean
Y_std = Y_train.std()
Y_train /= Y_std
Y_test -= Y_mean
Y_test /= Y_std

# %%
X_train.dtypes
# Out:
# Cement (component 1)(kg in a m^3 mixture)                float64
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    float64
# Fly Ash (component 3)(kg in a m^3 mixture)               float64
# Water  (component 4)(kg in a m^3 mixture)                float64
# Superplasticizer (component 5)(kg in a m^3 mixture)      float64
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     float64
# Fine Aggregate (component 7)(kg in a m^3 mixture)        float64
# Age (day)                                                float64
# dtype: object

# %%
X_train = X_train.to_numpy()
Y_train = Y_train.to_numpy()
X_test = X_test.to_numpy()
Y_test = Y_test.to_numpy()

# %%
network = M.Sequential()

# %%
network.add(L.Dense(128,activation="relu",input_shape=(X_train.shape[1],)))

# %%
network.add(L.Dense(64,activation="relu"))

# %%
network.add(L.Dense(32,activation="relu"))

# %%
network.add(L.Dense(1))

# %%
network.compile(optimizer="rmsprop",loss=["mse"],metrics=["mae"])

# %%
history = network.fit(X_train,Y_train,epochs=100,validation_split=0.3)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 15ms/step - loss: 0.6612 - mae: 0.6453 - val_loss: 0.4179 - val_mae: 0.5249
# Epoch 2/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3165 - mae: 0.4563 - val_loss: 0.3350 - val_mae: 0.4543
# Epoch 3/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2643 - mae: 0.4076 - val_loss: 0.2900 - val_mae: 0.4123
# Epoch 4/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2446 - mae: 0.3817 - val_loss: 0.2630 - val_mae: 0.3871
# Epoch 5/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1990 - mae: 0.3446 - val_loss: 0.2796 - val_mae: 0.4281
# Epoch 6/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1607 - mae: 0.3153 - val_loss: 0.2436 - val_mae: 0.3816
# Epoch 7/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1375 - mae: 0.2843 - val_loss: 0.2514 - val_mae: 0.3716
# Epoch 8/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1453 - mae: 0.2886 - val_loss: 0.2098 - val_mae: 0.3489
# Epoch 9/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1162 - mae: 0.2709 - val_loss: 0.2156 - val_mae: 0.3529
# Epoch 10/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1169 - mae: 0.2687 - val_loss: 0.1973 - val_mae: 0.3373
# Epoch 11/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1175 - mae: 0.2700 - val_loss: 0.2061 - val_mae: 0.3466
# Epoch 12/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1048 - mae: 0.2527 - val_loss: 0.2154 - val_mae: 0.3515
# Epoch 13/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1014 - mae: 0.2427 - val_loss: 0.1895 - val_mae: 0.3316
# Epoch 14/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0826 - mae: 0.2228 - val_loss: 0.1749 - val_mae: 0.3142
# Epoch 15/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0959 - mae: 0.2416 - val_loss: 0.1834 - val_mae: 0.3215
# Epoch 16/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0811 - mae: 0.2285 - val_loss: 0.2134 - val_mae: 0.3325
# Epoch 17/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0858 - mae: 0.2244 - val_loss: 0.1733 - val_mae: 0.3171
# Epoch 18/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0791 - mae: 0.2168 - val_loss: 0.1956 - val_mae: 0.3426
# Epoch 19/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0784 - mae: 0.2142 - val_loss: 0.1813 - val_mae: 0.3161
# Epoch 20/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0708 - mae: 0.2078 - val_loss: 0.1889 - val_mae: 0.3174
# Epoch 21/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0876 - mae: 0.2188 - val_loss: 0.1589 - val_mae: 0.3030
# Epoch 22/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0851 - mae: 0.2206 - val_loss: 0.1598 - val_mae: 0.3041
# Epoch 23/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0541 - mae: 0.1837 - val_loss: 0.1902 - val_mae: 0.3384
# Epoch 24/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0669 - mae: 0.1946 - val_loss: 0.1535 - val_mae: 0.2988
# Epoch 25/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0714 - mae: 0.2073 - val_loss: 0.1567 - val_mae: 0.3011
# Epoch 26/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0616 - mae: 0.1846 - val_loss: 0.1505 - val_mae: 0.2950
# Epoch 27/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0531 - mae: 0.1714 - val_loss: 0.1549 - val_mae: 0.3011
# Epoch 28/100
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0579 - mae: 0.1799 - val_loss: 0.1513 - val_mae: 0.2916
# Epoch 29/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0594 - mae: 0.1857 - val_loss: 0.1536 - val_mae: 0.2946
# Epoch 30/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0490 - mae: 0.1660 - val_loss: 0.1495 - val_mae: 0.2961
# Epoch 31/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0600 - mae: 0.1845 - val_loss: 0.1491 - val_mae: 0.2857
# Epoch 32/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0417 - mae: 0.1560 - val_loss: 0.1585 - val_mae: 0.2924
# Epoch 33/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0635 - mae: 0.1962 - val_loss: 0.1481 - val_mae: 0.2888
# Epoch 34/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0520 - mae: 0.1779 - val_loss: 0.1505 - val_mae: 0.2997
# Epoch 35/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0572 - mae: 0.1751 - val_loss: 0.1509 - val_mae: 0.2912
# Epoch 36/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0451 - mae: 0.1586 - val_loss: 0.1396 - val_mae: 0.2810
# Epoch 37/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0493 - mae: 0.1691 - val_loss: 0.1464 - val_mae: 0.2872
# Epoch 38/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0404 - mae: 0.1487 - val_loss: 0.1343 - val_mae: 0.2778
# Epoch 39/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0469 - mae: 0.1658 - val_loss: 0.1372 - val_mae: 0.2832
# Epoch 40/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0461 - mae: 0.1611 - val_loss: 0.1477 - val_mae: 0.2842
# Epoch 41/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0526 - mae: 0.1713 - val_loss: 0.1726 - val_mae: 0.3223
# Epoch 42/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0503 - mae: 0.1713 - val_loss: 0.1319 - val_mae: 0.2769
# Epoch 43/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0396 - mae: 0.1484 - val_loss: 0.1474 - val_mae: 0.2871
# Epoch 44/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0432 - mae: 0.1557 - val_loss: 0.1443 - val_mae: 0.2828
# Epoch 45/100
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0432 - mae: 0.1580 - val_loss: 0.1349 - val_mae: 0.2843
# Epoch 46/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0346 - mae: 0.1383 - val_loss: 0.1682 - val_mae: 0.3105
# Epoch 47/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0552 - mae: 0.1741 - val_loss: 0.1493 - val_mae: 0.2978
# Epoch 48/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0466 - mae: 0.1608 - val_loss: 0.1258 - val_mae: 0.2691
# Epoch 49/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0394 - mae: 0.1514 - val_loss: 0.1421 - val_mae: 0.2813
# Epoch 50/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0348 - mae: 0.1391 - val_loss: 0.1347 - val_mae: 0.2757
# Epoch 51/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0343 - mae: 0.1393 - val_loss: 0.1373 - val_mae: 0.2762
# Epoch 52/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0399 - mae: 0.1499 - val_loss: 0.1409 - val_mae: 0.2941
# Epoch 53/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0403 - mae: 0.1513 - val_loss: 0.1353 - val_mae: 0.2733
# Epoch 54/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0368 - mae: 0.1412 - val_loss: 0.1354 - val_mae: 0.2762
# Epoch 55/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0378 - mae: 0.1430 - val_loss: 0.1313 - val_mae: 0.2839
# Epoch 56/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0377 - mae: 0.1474 - val_loss: 0.1376 - val_mae: 0.2762
# Epoch 57/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0326 - mae: 0.1359 - val_loss: 0.1496 - val_mae: 0.2903
# Epoch 58/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0453 - mae: 0.1524 - val_loss: 0.1722 - val_mae: 0.3071
# Epoch 59/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0537 - mae: 0.1597 - val_loss: 0.1299 - val_mae: 0.2672
# Epoch 60/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0304 - mae: 0.1278 - val_loss: 0.1369 - val_mae: 0.2874
# Epoch 61/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0360 - mae: 0.1364 - val_loss: 0.1256 - val_mae: 0.2600
# Epoch 62/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0317 - mae: 0.1307 - val_loss: 0.1200 - val_mae: 0.2592
# Epoch 63/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0430 - mae: 0.1422 - val_loss: 0.1467 - val_mae: 0.2952
# Epoch 64/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0340 - mae: 0.1348 - val_loss: 0.1238 - val_mae: 0.2595
# Epoch 65/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0288 - mae: 0.1232 - val_loss: 0.1372 - val_mae: 0.2775
# Epoch 66/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0315 - mae: 0.1376 - val_loss: 0.1210 - val_mae: 0.2688
# Epoch 67/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0277 - mae: 0.1250 - val_loss: 0.1320 - val_mae: 0.2651
# Epoch 68/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0329 - mae: 0.1324 - val_loss: 0.1454 - val_mae: 0.2924
# Epoch 69/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0393 - mae: 0.1518 - val_loss: 0.1231 - val_mae: 0.2706
# Epoch 70/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0318 - mae: 0.1277 - val_loss: 0.1322 - val_mae: 0.2667
# Epoch 71/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0402 - mae: 0.1386 - val_loss: 0.1187 - val_mae: 0.2566
# Epoch 72/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0307 - mae: 0.1203 - val_loss: 0.1223 - val_mae: 0.2631
# Epoch 73/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0328 - mae: 0.1293 - val_loss: 0.1356 - val_mae: 0.2695
# Epoch 74/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0346 - mae: 0.1421 - val_loss: 0.1217 - val_mae: 0.2625
# Epoch 75/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0402 - mae: 0.1376 - val_loss: 0.1389 - val_mae: 0.2692
# Epoch 76/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0394 - mae: 0.1505 - val_loss: 0.1336 - val_mae: 0.2729
# Epoch 77/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0286 - mae: 0.1253 - val_loss: 0.1436 - val_mae: 0.2927
# Epoch 78/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0438 - mae: 0.1542 - val_loss: 0.1192 - val_mae: 0.2608
# Epoch 79/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0283 - mae: 0.1232 - val_loss: 0.1321 - val_mae: 0.2706
# Epoch 80/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0399 - mae: 0.1453 - val_loss: 0.1175 - val_mae: 0.2574
# Epoch 81/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0279 - mae: 0.1207 - val_loss: 0.1262 - val_mae: 0.2600
# Epoch 82/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0272 - mae: 0.1239 - val_loss: 0.1196 - val_mae: 0.2718
# Epoch 83/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0360 - mae: 0.1369 - val_loss: 0.1221 - val_mae: 0.2706
# Epoch 84/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0316 - mae: 0.1308 - val_loss: 0.1148 - val_mae: 0.2549
# Epoch 85/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0312 - mae: 0.1217 - val_loss: 0.1177 - val_mae: 0.2550
# Epoch 86/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0351 - mae: 0.1351 - val_loss: 0.1302 - val_mae: 0.2731
# Epoch 87/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0303 - mae: 0.1305 - val_loss: 0.1297 - val_mae: 0.2638
# Epoch 88/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0286 - mae: 0.1209 - val_loss: 0.1146 - val_mae: 0.2451
# Epoch 89/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0209 - mae: 0.0978 - val_loss: 0.1328 - val_mae: 0.2628
# Epoch 90/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0338 - mae: 0.1323 - val_loss: 0.1191 - val_mae: 0.2506
# Epoch 91/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0325 - mae: 0.1250 - val_loss: 0.1214 - val_mae: 0.2582
# Epoch 92/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0351 - mae: 0.1357 - val_loss: 0.1170 - val_mae: 0.2514
# Epoch 93/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0262 - mae: 0.1207 - val_loss: 0.1294 - val_mae: 0.2664
# Epoch 94/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0244 - mae: 0.1092 - val_loss: 0.1203 - val_mae: 0.2513
# Epoch 95/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0318 - mae: 0.1258 - val_loss: 0.1309 - val_mae: 0.2676
# Epoch 96/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0312 - mae: 0.1264 - val_loss: 0.1123 - val_mae: 0.2563
# Epoch 97/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0245 - mae: 0.1065 - val_loss: 0.1307 - val_mae: 0.2650
# Epoch 98/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0277 - mae: 0.1205 - val_loss: 0.1109 - val_mae: 0.2430
# Epoch 99/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0306 - mae: 0.1278 - val_loss: 0.1366 - val_mae: 0.2796
# Epoch 100/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0262 - mae: 0.1178 - val_loss: 0.1201 - val_mae: 0.2519

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
loss,mae=network.evaluate(X_test,Y_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1162 - mae: 0.2378

# %%
val_mae = history.history['val_mae']
val_loss = history.history['val_loss']

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(100)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc_values = history_dict['mae']
val_acc_values = history_dict['val_mae']
plt.plot(epochs, acc_values, 'bo', label='Training mae')
plt.plot(epochs, val_acc_values, 'b', label='Validation mae')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %%
y_pred = network.predict(X_test)

# %%
def denorm(x):
    return (x * Y_std) + Y_mean

# %%
y_pred = denorm(y_pred)

# %%
y_true = denorm(Y_test)

# %%
y_pred = y_pred.flatten()

# %%
y_pred.shape
# Out:
# (309,)

# %%
y_true.shape
# Out:
# (309,)

# %%
coef = np.polyfit(y_true,y_pred,1)
poly1d_fn = np.poly1d(coef) 
# poly1d_fn is now a function which takes in x and returns an estimate for y

plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
plt.xlim(0, 100)
plt.ylim(0, 100)
# Out:
# (0.0, 100.0)
